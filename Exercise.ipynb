# %%
from absenteeism_module import * 

pd.read_csv('Absenteeism_new_data.csv').head()

model = absenteeism_model('model','scaler')

model.load_and_clean_data('Absenteeism_new_data.csv')

outputs = model.predicted_outputs()
outputs
# Out:
#     Reason_1  Reason_2  Reason_3  Reason_4  Month  Transportation Expense  \
# 0          0       0.0         0         1      6                     179
# 1          1       0.0         0         0      6                     361
# 2          0       0.0         0         1      6                     155
# 3          0       0.0         0         1      6                     179
# 4          1       0.0         0         0      6                     155
# 5          1       0.0         0         0      6                     225
# 6          1       0.0         0         0      6                     118
# 7          0       0.0         0         1      6                     179
# 8          0       0.0         0         1      6                     118
# 9          1       0.0         0         0      6                     118
# 10         0       0.0         0         1      6                     378
# 11         0       0.0         1         0      6                     118
# ...

# %%
outputs.to_csv('Absenteeism_predictions.csv',index = False)
