# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from sklearn.linear_model import LinearRegression

# %%
raw_data = pd.read_csv('Absenteeism-data.csv')
df = raw_data.copy()

# %%
df = df.drop(['ID'], axis = 1)
df.head()
# Out:
#    Reason for Absence        Date  Transportation Expense  Distance to Work  \
# 0                  26  07/07/2015                     289                36
# 1                   0  14/07/2015                     118                13
# 2                  23  15/07/2015                     179                51
# 3                   7  16/07/2015                     279                 5
# 4                  23  23/07/2015                     289                36
#
#    Age  Daily Work Load Average  Body Mass Index  Education  Children  Pets  \
# 0   33                  239.554               30          1         2     1
# 1   50                  239.554               31          1         1     0
# 2   38                  239.554               31          1         0     0
# 3   39                  239.554               24          1         2     0
# 4   33                  239.554               30          1         2     1
#
#    Absenteeism Time in Hours
# ...

# %%
reason_columns = pd.get_dummies(df['Reason for Absence'], drop_first = True)
reason_columns

df = df.drop(['Reason for Absence'],axis = 1)

# %%
reason_type_1 = reason_columns.loc[:,1:14].max(axis = 1)
reason_type_2 = reason_columns.loc[:,15:17].max(axis = 1)
reason_type_3 = reason_columns.loc[:,18:21].max(axis = 1)
reason_type_4 = reason_columns.loc[:,22:].max(axis = 1)

df = pd.concat([df,reason_type_1,reason_type_2,reason_type_3,reason_type_4],axis = 1)
df
# Out:
#            Date  Transportation Expense  Distance to Work  Age  \
# 0    07/07/2015                     289                36   33
# 1    14/07/2015                     118                13   50
# 2    15/07/2015                     179                51   38
# 3    16/07/2015                     279                 5   39
# 4    23/07/2015                     289                36   33
# ..          ...                     ...               ...  ...
# 695  23/05/2018                     179                22   40
# 696  23/05/2018                     225                26   28
# 697  24/05/2018                     330                16   28
# 698  24/05/2018                     235                16   32
# 699  31/05/2018                     291                31   40
#
#      Daily Work Load Average  Body Mass Index  Education  Children  Pets  \
# 0                    239.554               30          1         2     1
# ...

# %%
df.columns.values
# Out:
# array(['Date', 'Transportation Expense', 'Distance to Work', 'Age',
#        'Daily Work Load Average', 'Body Mass Index', 'Education',
#        'Children', 'Pets', 'Absenteeism Time in Hours', 0, 1, 2, 3],
#       dtype=object)

# %%
cols = ['Date', 'Transportation Expense', 'Distance to Work', 'Age',
       'Daily Work Load Average', 'Body Mass Index', 'Education',
       'Children', 'Pets', 'Absenteeism Time in Hours', 'Reason_1', 'Reason_2', 'Reason_3', 'Reason_4']

# %%
df.columns = cols

df_reason = df[cols]
df_reason.head()
# Out:
#          Date  Transportation Expense  Distance to Work  Age  \
# 0  07/07/2015                     289                36   33
# 1  14/07/2015                     118                13   50
# 2  15/07/2015                     179                51   38
# 3  16/07/2015                     279                 5   39
# 4  23/07/2015                     289                36   33
#
#    Daily Work Load Average  Body Mass Index  Education  Children  Pets  \
# 0                  239.554               30          1         2     1
# 1                  239.554               31          1         1     0
# 2                  239.554               31          1         0     0
# 3                  239.554               24          1         2     0
# 4                  239.554               30          1         2     1
#
#    Absenteeism Time in Hours  Reason_1  Reason_2  Reason_3  Reason_4
# 0                          4         0         0         0         1
# ...

# %%
cols = ['Reason_1', 'Reason_2', 'Reason_3', 'Reason_4', 'Date', 'Transportation Expense', 'Distance to Work', 'Age',
       'Daily Work Load Average', 'Body Mass Index', 'Education',
       'Children', 'Pets', 'Absenteeism Time in Hours']

# %%
df_r = df_reason[cols]
df_r.head()
# Out:
#    Reason_1  Reason_2  Reason_3  Reason_4        Date  Transportation Expense  \
# 0         0         0         0         1  07/07/2015                     289
# 1         0         0         0         0  14/07/2015                     118
# 2         0         0         0         1  15/07/2015                     179
# 3         1         0         0         0  16/07/2015                     279
# 4         0         0         0         1  23/07/2015                     289
#
#    Distance to Work  Age  Daily Work Load Average  Body Mass Index  Education  \
# 0                36   33                  239.554               30          1
# 1                13   50                  239.554               31          1
# 2                51   38                  239.554               31          1
# 3                 5   39                  239.554               24          1
# 4                36   33                  239.554               30          1
#
# ...

# %%
df_r['Date'] = pd.to_datetime(df_r['Date'],format = '%d/%m/%Y')
df_r
# Out:
#      Reason_1  Reason_2  Reason_3  Reason_4       Date  \
# 0           0         0         0         1 2015-07-07
# 1           0         0         0         0 2015-07-14
# 2           0         0         0         1 2015-07-15
# 3           1         0         0         0 2015-07-16
# 4           0         0         0         1 2015-07-23
# ..        ...       ...       ...       ...        ...
# 695         1         0         0         0 2018-05-23
# 696         1         0         0         0 2018-05-23
# 697         1         0         0         0 2018-05-24
# 698         0         0         0         1 2018-05-24
# 699         0         0         0         1 2018-05-31
#
#      Transportation Expense  Distance to Work  Age  Daily Work Load Average  \
# 0                       289                36   33                  239.554
# 1                       118                13   50                  239.554
# ...

# %%
def date_to_weekday(date_value):
    return date_value.weekday() +1

# %%
def date_to_month(date_value):
    return date_value.month

# %%
df_r['Month'] = df_r['Date'].apply(date_to_month)
df_r['Day'] = df_r['Date'].apply(date_to_weekday)
df_r.head()
# Out:
#    Reason_1  Reason_2  Reason_3  Reason_4       Date  Transportation Expense  \
# 0         0         0         0         1 2015-07-07                     289
# 1         0         0         0         0 2015-07-14                     118
# 2         0         0         0         1 2015-07-15                     179
# 3         1         0         0         0 2015-07-16                     279
# 4         0         0         0         1 2015-07-23                     289
#
#    Distance to Work  Age  Daily Work Load Average  Body Mass Index  Education  \
# 0                36   33                  239.554               30          1
# 1                13   50                  239.554               31          1
# 2                51   38                  239.554               31          1
# 3                 5   39                  239.554               24          1
# 4                36   33                  239.554               30          1
#
# ...

# %%
#list_month = []
#list_days = []
#for i in range(df_r.shape[0]):
#    list_month.append(df_r['Date'][i].month)
#    list_days.append(df_r['Date'][i].weekday()+1)
#df_r['Month'] = list_month
#df_r['Day'] = list_days
#df_r.head(100)

# %%
df_r = df_r.drop(['Date'],axis = 1)
df_r.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-175-a1af649b0c84> in <module>
# ----> 1 df_r = df_r.drop(['Date'],axis = 1)
#       2 df_r.head()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
df_r.head()
# Out:
#    Reason_1  Reason_2  Reason_3  Reason_4  Transportation Expense  \
# 0         0         0         0         1                     289
# 1         0         0         0         0                     118
# 2         0         0         0         1                     179
# 3         1         0         0         0                     279
# 4         0         0         0         1                     289
#
#    Distance to Work  Age  Daily Work Load Average  Body Mass Index  Education  \
# 0                36   33                  239.554               30          1
# 1                13   50                  239.554               31          1
# 2                51   38                  239.554               31          1
# 3                 5   39                  239.554               24          1
# 4                36   33                  239.554               30          1
#
#    Children  Pets  Absenteeism Time in Hours  Month  Day
# ...

# %%
df_r.columns
# Out:
# Index(['Reason_1', 'Reason_2', 'Reason_3', 'Reason_4',
#        'Transportation Expense', 'Distance to Work', 'Age',
#        'Daily Work Load Average', 'Body Mass Index', 'Education', 'Children',
#        'Pets', 'Absenteeism Time in Hours', 'Month', 'Day'],
#       dtype='object')

# %%
cols = [ 'Reason_1', 'Reason_2', 'Reason_3', 'Reason_4', 'Month', 'Day',
       'Transportation Expense', 'Distance to Work', 'Age',
       'Daily Work Load Average', 'Body Mass Index', 'Education', 'Children',
       'Pets', 'Absenteeism Time in Hours']

# %%
df_rd = df_r[cols]
df_rd.head()
# Out:
#    Reason_1  Reason_2  Reason_3  Reason_4  Month  Day  Transportation Expense  \
# 0         0         0         0         1      7    2                     289
# 1         0         0         0         0      7    2                     118
# 2         0         0         0         1      7    3                     179
# 3         1         0         0         0      7    4                     279
# 4         0         0         0         1      7    4                     289
#
#    Distance to Work  Age  Daily Work Load Average  Body Mass Index  Education  \
# 0                36   33                  239.554               30          1
# 1                13   50                  239.554               31          1
# 2                51   38                  239.554               31          1
# 3                 5   39                  239.554               24          1
# 4                36   33                  239.554               30          1
#
# ...

# %%
df_rd['Education'].unique()
# Out:
# array([1, 3, 2, 4])

# %%
df_rd['Education'] = data_with_dummies['Education'].map({1:0,2:1,3:1,4:1})

# %%
df_rd
# Out:
#      Reason_1  Reason_2  Reason_3  Reason_4  Month  Day  \
# 0           0         0         0         1      7    2
# 1           0         0         0         0      7    2
# 2           0         0         0         1      7    3
# 3           1         0         0         0      7    4
# 4           0         0         0         1      7    4
# ..        ...       ...       ...       ...    ...  ...
# 695         1         0         0         0      5    3
# 696         1         0         0         0      5    3
# 697         1         0         0         0      5    4
# 698         0         0         0         1      5    4
# 699         0         0         0         1      5    4
#
#      Transportation Expense  Distance to Work  Age  Daily Work Load Average  \
# 0                       289                36   33                  239.554
# 1                       118                13   50                  239.554
# ...

# %%
df_preprocessed = df_rd.copy()
df_preprocessed.to_csv('Absenteeism-data-preprocessed.csv', index = False)
df_preprocessed.head()
# Out:
#    Reason_1  Reason_2  Reason_3  Reason_4  Month  Day  Transportation Expense  \
# 0         0         0         0         1      7    2                     289
# 1         0         0         0         0      7    2                     118
# 2         0         0         0         1      7    3                     179
# 3         1         0         0         0      7    4                     279
# 4         0         0         0         1      7    4                     289
#
#    Distance to Work  Age  Daily Work Load Average  Body Mass Index  Education  \
# 0                36   33                  239.554               30          0
# 1                13   50                  239.554               31          0
# 2                51   38                  239.554               31          0
# 3                 5   39                  239.554               24          0
# 4                36   33                  239.554               30          0
#
# ...

# %%
data_preprocessed = data_with_dummies[cols]
data_preprocessed.head()
# Out:
#   Day Month  Transportation Expense  Distance to Work  Age  \
# 0  07    07                     289                36   33
# 1  14    07                     118                13   50
# 2  15    07                     179                51   38
# 3  16    07                     279                 5   39
# 4  23    07                     289                36   33
#
#    Daily Work Load Average  Body Mass Index  Education  Children  Pets  ...  \
# 0                  239.554               30        NaN         2     1  ...
# 1                  239.554               31        NaN         1     0  ...
# 2                  239.554               31        NaN         0     0  ...
# 3                  239.554               24        NaN         2     0  ...
# 4                  239.554               30        NaN         2     1  ...
#
#    Reason for Absence_18  Reason for Absence_19  Reason for Absence_21  \
# 0                      0                      0                      0
# ...
